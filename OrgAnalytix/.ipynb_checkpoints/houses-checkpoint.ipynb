# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def clean_data(fname='edge_data/asoiaf/data/asoiaf-all-edges.csv'):
    df = pd.read_csv(fname)
    df = df[df['Source'].isin(df['Source'].value_counts()[df['Source'].value_counts()>=2].index)]
    df = df[df['Target'].isin(df['Target'].value_counts()[df['Target'].value_counts()>=2].index)]
    return df

# %%
b1_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book1-edges.csv')
b2_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book2-edges.csv')
b3_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book3-edges.csv')
b4_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book4-edges.csv')
b45_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book45-edges.csv')
b5_df = clean_data(fname='edge_data/asoiaf/data/asoiaf-book5-edges.csv')

# %%
def get_egos_for_char(charname):
    graphs = []
    pgr = []
    book = 0
    for d in [b1_df,b2_df,b3_df,b4_df,b45_df,b5_df]:
        book += 1
        G = nx.DiGraph(nx.convert_matrix.from_pandas_dataframe(d, source = "Source", target = "Target"))
        try:
            ego = nx.ego_graph(G, charname, radius = 1)
            graphs.append(ego)
            #pgr.append(nx.pagerank(G, charname))
        except:
            print("{} not in book{}".format(charname, book))
            pass
    return (graphs, pgr)

# %%
cname = "Janos-Slynt"

# %%
test = get_egos_for_char(cname)
# Out:
# Janos-Slynt not in book4

# %%
def plot_egos(charname):
    egos, scores = get_egos_for_char(charname)
    fig, axes = plt.subplots(2,3,figsize = (15,10))
    for i, ax in enumerate(axes.flatten()):
        ax.set_xticks([])
        ax.set_yticks([])
        try:
            ax.set_xlabel("Degrees for {}: {}/nPagerank Score:{}".format(cname, nx.degree(egos[i],cname), scores[i]), fontsize=15)
            nx.draw_networkx(egos[i], with_labels = False, ax = ax)
        except:
            pass

# %%
plot_egos(cname)
# Out:
# Janos-Slynt not in book4

# %%
def_edges1.head()
# Out:
#            Source            Target        Type  id  weight       FromHouse  \
# 0  Addam-Marbrand     Brynden-Tully  Undirected   0       3  House Marbrand
# 1  Addam-Marbrand  Cersei-Lannister  Undirected   1       3  House Marbrand
# 2  Addam-Marbrand       Gyles-Rosby  Undirected   2       3  House Marbrand
# 3  Addam-Marbrand   Jaime-Lannister  Undirected   3      14  House Marbrand
# 4  Addam-Marbrand      Jalabhar-Xho  Undirected   4       3  House Marbrand
#
#             ToHouse
# 0  House StarkHouse
# 1   House Lannister
# 2       House Rosby
# 3        Kingsguard
# 4    Summer Islands

# %%
print(def_edges.shape,def_edges1.shape)
# Out:
# (2823, 7) (2391, 7)

# %%
def_edges.loc[def_edges['Source'] == "Aemon-Targaryen-(Dragonknight)"]
# Out:
#                             Source           Target        Type  id  weight  \
# 41  Aemon-Targaryen-(Dragonknight)  Jaime-Lannister  Undirected  41       3
#
#     FromHouse     ToHouse
# 41  Targaryen  Kingsguard

# %%
G = nx.MultiDiGraph(nx.convert_matrix.from_pandas_dataframe(def_edges1, source = "Source", target = "Target"))

# %%
nx.draw_networkx(G)

# %%
def get_all_names(df):
    ppl = def_edges['Source'].unique()
    ppl1 = def_edges['Target'].unique()
    ppl = np.append(ppl1, ppl)
    ppl = [i.replace('-','_') for i in ppl]
    ppl = list(set(ppl))
    return ppl

# %%
def get_house_from_wiki(character):
    '''
    Function to scrape a character's house allegiance from the Game of Thrones Wiki
    
    Input:
    character - String: Character name formatted as on the wiki page
    
    Output:
    House (or other organization) allegiance of character
    '''
    
    i = character
    
    if i.endswith('Baratheon'):
        return "House Baratheon"
    elif i.endswith("Targaryen"):
        return "House Targaryen"
    elif i.endswith('Stark'):
        return "House Stark"
    elif i.endswith('Greyjoy'):
        return "House Greyjoy"
    else:
    
        #Get character name in separated list
        char_name = i.split('_')

        #Get page from wiki
        page = requests.get('http://awoiaf.westeros.org/index.php/{}'.format(i))

        #Parse html from page
        soup = BeautifulSoup(page.content, 'html.parser')

        try:
            #Pull table rows out of infobox section of wiki page
            for tr in soup.find('table', class_='infobox infobox-body'):

                #Get only table row for house allegiance
                if tr.text.startswith('Allegiance'):

                    #Drop the word Allegiance and trailing space from start of row
                    allegiances = tr.text[12:].split('[')[0].lstrip("The ")

                    #Find where capital letters occur and get indices
                    #for cases where more than one allegiance is mentioned
                    caps = [i.isupper() for i in allegiances]
                    cap_idx = [j for j, k in (enumerate(caps)) if k == True]

                    #If no allegiance is mentioned on the wiki page, print name and return character surname
                    if allegiances == None:
                        print("No allegiance listed for {}. Attempting to use surname".format(i))
                        return i.split('(')[0].rstrip('_').split('_')[-1]
                    
                    if allegiances.endswith("Kingsguard"):
                        return "Kingsguard"

                    #If only one house or organization is listed    
                    elif len(allegiances.split()) <= 2:
                        if len(cap_idx) == 3:
                            return allegiances[:cap_idx[2]]
                        else:
                            return allegiances

                    elif allegiances.startswith("City Watch"):
                        return "City Watch"

                    else:
                        return ' '.join(allegiances[cap_idx[2]:].split()[:2])
        except:
            #print("No page found for {}. Attempting to use surname.".format(i))
            return i.split('(')[0].rstrip('_').split('_')[-1]

# %%
chars_by_houses = [get_house_from_wiki(i) for i in ppl]

# %%
list(enumerate(chars_by_houses))
# Out:
# [(0, 'Kingsguard'),
#  (1, 'House Baratheon'),
#  (2, "King's Landing"),
#  (3, 'Will'),
#  (4, 'House Targaryen'),
#  (5, None),
#  (6, 'House Florent'),
#  (7, None),
#  (8, "Night's Watch"),
#  (9, None),
#  (10, "Night's Watch"),
#  (11, None),
#  (12, 'Brave Companions'),
#  (13, 'Kingsguard'),
#  (14, 'Gates of'),
#  (15, None),
#  (16, 'House Bolton'),
#  (17, 'Galare'),
#  (18, 'House Baratheon'),
#  (19, 'House Lefford'),
#  (20, 'House Lannister'),
#  (21, 'Kingsguard'),
#  (22, 'Brave Companions'),
#  (23, 'House Lannister'),
#  (24, 'House Lannister'),
#  (25, 'House Baratheon'),
#  (26, 'Tower of'),
#  (27, 'House Whent'),
#  (28, 'Stone men'),
#  (29, 'Tyrell'),
#  (30, 'House Martell'),
#  (31, 'Unsullied'),
#  (32, 'Most Devout'),
#  (33, None),
#  (34, 'Stone Crows'),
#  (35, 'Stone Crows'),
#  (36, 'Kingsguard'),
#  (37, 'House Targaryen'),
#  (38, 'Stiv'),
#  (39, None),
#  (40, 'House Arryn'),
#  (41, 'Stone Crows'),
#  (42, 'House Borrell'),
#  (43, 'House Piper'),
#  (44, None),
#  (45, None),
#  (46, 'Grazhar'),
#  (47, None),
#  (48, 'Drowned men'),
#  (49, "Wayfarer's Rest"),
#  (50, None),
#  (51, None),
#  (52, 'House Norrey'),
#  (53, 'House Clegane'),
#  (54, 'House Stokeworth'),
#  (55, "Night's Watch"),
#  (56, 'Hghar'),
#  (57, 'Anguy'),
#  (58, "Night's Watch"),
#  (59, "Night's Watch"),
#  (60, 'Greenbeard'),
#  (61, None),
#  (62, 'SparrowsFaith Militant'),
#  (63, 'Happy Port'),
#  (64, 'House Lannister'),
#  (65, 'Burned Men'),
#  (66, 'House Stark'),
#  (67, 'Lords Declarant'),
#  (68, "Night's Watch"),
#  (69, None),
#  (70, 'Targaryen'),
#  (71, 'House Baratheon'),
#  (72, 'Garth'),
#  (73, "Night's Watch"),
#  (74, 'House Hetherspoon'),
#  (75, 'House Arryn'),
#  (76, 'Scolera'),
#  (77, "Night's Watch"),
#  (78, 'House StarkHouse'),
#  (79, None),
#  (80, 'iger'),
#  (81, None),
#  (82, 'FingersHouse Baelish'),
#  (83, 'White'),
#  (84, "Night's Watch"),
#  (85, 'House Targaryen'),
#  (86, 'House Greyjoy'),
#  (87, 'House Frey'),
#  (88, None),
#  (89, 'House Arryn'),
#  (90, 'House Baratheon'),
#  (91, 'House Lannister'),
#  (92, 'House Westerling'),
#  (93, None),
#  (94, 'nnsHouse Thenn'),
#  (95, 'Lords Declarant'),
#  (96, None),
#  (97, 'House Heddle'),
#  (98, None),
#  (99, 'House Celtigar'),
#  (100, 'House Baratheon'),
#  (101, None),
#  (102, 'Rainbow Guard'),
#  (103, 'House Redfort'),
#  (104, 'House Bolton'),
#  (105, 'Khal Drogo'),
#  (106, 'House Frey'),
#  (107, 'House Mormont'),
#  (108, 'House Baratheon'),
#  (109, 'House Lannister'),
#  (110, 'House Lannister'),
#  (111, None),
#  (112, 'Lucky'),
#  (113, 'House Bolton'),
#  (114, 'House Umber'),
#  (115, 'House Ryswell'),
#  (116, 'Martell'),
#  (117, 'House Arryn'),
#  (118, 'Lords Declarant'),
#  (119, 'House Bolton'),
#  (120, 'House Baratheon'),
#  (121, "Alchemists' Guild"),
#  (122, 'House Clegane'),
#  (123, "Night's Watch"),
#  (124, 'House Cassel'),
#  (125, 'House Manderly'),
#  (126, "Night's Watch"),
#  (127, 'House Tyrell'),
#  (128, 'Golden Company'),
#  (129, 'House Targaryen'),
#  (130, 'House Karstark'),
#  (131, 'House Rosby'),
#  (132, 'House Tully'),
#  (133, 'House Seaworth'),
#  (134, 'House Darry'),
#  (135, 'House Hunter'),
#  (136, "Night's Watch"),
#  (137, None),
#  (138, 'Robin'),
#  (139, "DragonstoneQueen's men"),
#  (140, 'House Targaryen'),
#  (141, 'House Manderly'),
#  (142, "Night's Watch"),
#  (143, 'House Baratheon'),
#  (144, 'House Mormont'),
#  (145, 'House Baratheon'),
#  (146, 'Summer Islands'),
#  (147, 'House Greyjoy'),
#  (148, 'House Frey'),
#  (149, 'House Botley'),
#  (150, 'House Sunglass'),
#  (151, 'House Seaworth'),
#  (152, None),
#  (153, 'Kingsguard'),
#  (154, 'House Targaryen'),
#  (155, 'House Martell'),
#  (156, 'House Tyrell'),
#  (157, 'House Tallhart'),
#  (158, 'Giant'),
#  (159, 'House Baelish'),
#  (160, 'Kingswood Brotherhood'),
#  (161, 'Lords Declarant'),
#  (162, 'House Targaryen'),
#  (163, "Night's Watch"),
#  (164, 'Brave Companions'),
#  (165, 'House Stark'),
#  (166, 'UnsulliedHouse Targaryen'),
#  (167, 'House Umber'),
#  (168, 'House Redwyne'),
#  (169, 'House Baratheon'),
#  (170, 'House Targaryen'),
#  (171, 'House Dayne'),
#  (172, 'House Dalt'),
#  (173, 'House Lannister'),
#  (174, 'Mountain'),
#  (175, 'City Watch'),
#  (176, 'House Stark'),
#  (177, 'House Poole'),
#  (178, 'House Estermont'),
#  (179, None),
#  (180, None),
#  (181, "Night's Watch"),
#  (182, 'House Blackwood'),
#  (183, "Night's Watch"),
#  (184, 'House Yronwood'),
#  (185, 'House Greyjoy'),
#  (186, 'House Frey'),
#  (187, 'House Tallhart'),
#  (188, None),
#  (189, 'House Greyjoy'),
#  (190, 'House Redbeard'),
#  (191, 'House Tully'),
#  (192, None),
#  (193, 'House Hewett'),
#  (194, 'House Greyjoy'),
#  (195, 'House Frey'),
#  (196, 'Kingsguard'),
#  (197, "Night's Watch"),
#  (198, 'Kingsguard'),
#  (199, None),
#  (200, None),
#  (201, 'House Martell'),
#  (202, 'House Redwyne'),
#  (203, None),
#  (204, None),
#  (205, 'Banners'),
#  (206, None),
#  (207, 'Second Sons'),
#  (208, 'House Targaryen'),
#  (209, 'House Grafton'),
#  (210, 'Targaryen'),
#  (211, 'House Frey'),
#  (212, 'House Frey'),
#  (213, 'House Targaryen'),
#  (214, 'High Hermitage'),
#  (215, 'House Lannister'),
#  (216, "Night's Watch"),
#  (217, 'House Tyrell'),
#  (218, "Night's Watch"),
#  (219, None),
#  (220, 'House Mullendore'),
#  (221, "Night's Watch"),
#  (222, 'House Martell'),
#  (223, "Night's Watch"),
#  (224, None),
#  (225, "Night's Watch"),
#  (226, 'House Greyjoy'),
#  (227, None),
#  (228, 'Kingsguard'),
#  (229, None),
#  (230, 'House Crabb'),
#  (231, 'House Reed'),
#  (232, 'Brother'),
#  (233, 'House Targaryen'),
#  (234, 'House Peckledon'),
#  (235, 'Windblown'),
#  (236, 'House TargaryenHouse'),
#  (237, None),
#  (238, 'House Greyjoy'),
#  (239, None),
#  (240, "Chataya's brothel"),
#  (241, "Night's Watch"),
#  (242, 'Brotherhood without'),
#  (243, 'House Bolton'),
#  (244, "Night's Watch"),
#  (245, 'House Stark'),
#  (246, "Night's Watch"),
#  (247, 'Stormcrows'),
#  (248, 'House Stark'),
#  (249, None),
#  (250, 'House Lannister'),
#  (251, "House TullyNight's"),
#  (252, 'House Yronwood'),
#  (253, 'House Bolton'),
#  (254, 'Most Devout'),
#  (255, 'House Targaryen'),
#  (256, 'Melisandre'),
#  (257, 'House Greyjoy'),
#  (258, 'House Hunter'),
#  (259, 'House Targaryen'),
#  (260, 'Hareth'),
#  (261, 'House Mallister'),
#  (262, 'Dhan'),
#  (263, 'House Targaryen'),
#  (264, "Night's Watch"),
#  (265, None),
#  (266, 'House Redwyne'),
#  (267, 'House Payne'),
#  (268, 'Citadel'),
#  (269, 'House Baratheon'),
#  (270, 'House TargaryenSecond'),
#  (271, None),
#  (272, "Night's Watch"),
#  (273, 'House Frey'),
#  (274, None),
#  (275, 'Bloodbeard'),
#  (276, 'Kingsguard'),
#  (277, 'House Greyjoy'),
#  (278, "Night's Watch"),
#  (279, 'House Greyjoy'),
#  (280, 'House Stark'),
#  (281, 'House Frey'),
#  (282, 'Qezza'),
#  (283, 'House Varner'),
#  (284, 'House Dustin'),
#  (285, None),
#  (286, "Queen's men"),
#  (287, None),
#  (288, 'House Arryn'),
#  (289, 'House Stark'),
#  (290, 'House Serry'),
#  (291, "Night's Watch"),
#  (292, 'House Targaryen'),
#  (293, 'House Manderly'),
#  (294, 'House Stark'),
#  (295, 'Dragonstone'),
#  (296, None),
#  (297, 'House Tully'),
#  (298, 'Septon'),
#  (299, None),
#  (300, None),
#  (301, 'House Lannister'),
#  (302, 'Brightwater Keep'),
#  (303, 'House Stark'),
#  (304, "DragonstoneQueen's men"),
#  (305, None),
#  (306, "SonsIron ShieldsMaiden's"),
#  (307, None),
#  (308, 'House Karstark'),
#  (309, 'House Baratheon'),
#  (310, "Night's Watch"),
#  (311, 'House Targaryen'),
#  (312, 'House Westerling'),
#  (313, 'House Cassel'),
#  (314, 'House Mormont'),
#  (315, 'House Bolton'),
#  (316, 'House Lannister'),
#  (317, "Night's Watch"),
#  (318, 'House Greyjoy'),
#  (319, 'House Redwyne'),
#  (320, 'Me'),
#  (321, None),
#  (322, 'House Frey'),
#  (323, 'House Baratheon'),
#  (324, 'Kingswood Brotherhood'),
#  (325, 'City Watch'),
#  (326, 'Brave Companions'),
#  (327, None),
#  (328, 'Atranta'),
#  (329, None),
#  (330, 'House Martell'),
#  (331, 'House Targaryen'),
#  (332, 'House Hornwood'),
#  (333, None),
#  (334, "Night's Watch"),
#  (335, 'House TargaryenGolden'),
#  (336, 'House Lannister'),
#  (337, None),
#  (338, "Night's Watch"),
#  (339, 'House Targaryen'),
#  (340, "Night's Watch"),
#  (341, 'BrownhollowHouse Baelish'),
#  (342, 'House Baratheon'),
#  (343, "Night's Watch"),
#  (344, "Night's Watch"),
#  (345, 'Free Brothers'),
#  (346, 'House Merryweather'),
#  (347, 'House Clegane'),
#  (348, "Night's Watch"),
#  (349, 'House Merryweather'),
#  (350, 'Kingsguard'),
#  (351, 'House Targaryen'),
#  (352, 'House Greyjoy'),
#  (353, None),
#  (354, 'House Baelish'),
#  (355, None),
#  (356, 'House Baratheon'),
#  (357, 'Kingsguard'),
#  (358, None),
#  (359, None),
#  (360, 'House Bolton'),
#  (361, 'House Greyjoy'),
#  (362, 'House Frey'),
#  (363, 'Meribald'),
#  (364, None),
#  (365, 'Golden Company'),
#  (366, 'House Rowan'),
#  (367, "Mother's Men"),
#  (368, None),
#  (369, "Night's Watch"),
#  (370, 'Second Sons'),
#  (371, 'Faceless Men'),
#  (372, 'House Frey'),
#  (373, 'House Manderly'),
#  (374, 'House Bolton'),
#  (375, 'House Frey'),
#  (376, 'House Goodbrother'),
#  (377, 'Owen'),
#  (378, "Night's Watch"),
#  (379, 'House Baratheon'),
#  (380, 'House Stark'),
#  (381, 'House Bracken'),
#  (382, 'House Lannister'),
#  (383, 'nn'),
#  (384, 'Baratheon of'),
#  (385, None),
#  (386, 'House Targaryen'),
#  (387, "Night's Watch"),
#  (388, None),
#  (389, None),
#  (390, 'eye'),
#  (391, 'House Lannister'),
#  (392, 'House Waynwood'),
#  (393, 'House Targaryen'),
#  (394, 'House Westerling'),
#  (395, 'House Targaryen'),
#  (396, 'House Tyrell'),
#  (397, 'Shagwell'),
#  (398, 'House Corbray'),
#  (399, 'House Frey'),
#  (400, 'House Stark'),
#  (401, 'House Longwaters'),
#  (402, 'House Frey'),
#  (403, 'House Stark'),
#  (404, 'House Stark'),
#  (405, 'House Hornwood'),
#  (406, 'Lords Declarant'),
#  (407, 'House Manderly'),
#  (408, 'House Martell'),
#  (409, 'House Baratheon'),
#  (410, 'Wise Masters'),
#  (411, 'House Bolton'),
#  (412, "Night's Watch"),
#  (413, 'House Goodbrother'),
#  (414, None),
#  (415, None),
#  (416, 'Brave Companions'),
#  (417, 'Grey Garden'),
#  (418, 'House Frey'),
#  (419, 'Dragonstone'),
#  (420, "Night's Watch"),
#  (421, 'House Lannister'),
#  (422, None),
#  (423, 'House Hollard'),
#  (424, 'City Watch'),
#  (425, None),
#  (426, 'House Mormont'),
#  (427, 'House Drumm'),
#  (428, 'Mezzara'),
#  (429, None),
#  (430, 'House Arryn'),
#  (431, 'House Stark'),
#  (432, 'House Tyrell'),
#  (433, 'House Poole'),
#  (434, 'House Baratheon'),
#  (435, 'House Martell'),
#  (436, 'House Umber'),
#  (437, 'House TargaryenShavepatesBrazen'),
#  (438, 'DreadfortHouse Bolton'),
#  (439, 'Rainbow Guard'),
#  (440, 'Kingsguard'),
#  (441, 'House Tyrell'),
#  (442, 'New Barrel'),
#  (443, 'House Greyjoy'),
#  (444, None),
#  (445, "Night's Watch"),
#  (446, 'House Stark'),
#  (447, None),
#  (448, 'Elephants'),
#  (449, 'House Tarly'),
#  (450, None),
#  (451, None),
#  (452, 'Lem'),
#  (453, 'last greenseer'),
#  (454, 'House Tarth'),
#  (455, 'House Stark'),
#  (456, 'House Goodbrother'),
#  (457, 'House Lannister'),
#  (458, None),
#  (459, None),
#  (460, 'Great Masters'),
#  (461, 'Windblown'),
#  (462, 'Happy Port'),
#  (463, 'Huntsman'),
#  (464, None),
#  (465, 'House Baratheon'),
#  (466, 'House Arryn'),
#  (467, "Night's Watch"),
#  (468, 'House Targaryen'),
#  (469, 'Golden Company'),
#  (470, "Night's Watch"),
#  (471, 'House Glover'),
#  (472, 'House Stark'),
#  (473, 'House Whent'),
#  (474, 'House YronwoodWindblown'),
#  (475, "Queen's men"),
#  (476, 'House Bolton'),
#  (477, None),
#  (478, None),
#  (479, 'Stone Crows'),
#  (480, 'Drowned men'),
#  (481, 'House Crakehall'),
#  (482, 'House Codd'),
#  (483, 'House Targaryen'),
#  (484, 'Dragonstone'),
#  (485, 'City Watch'),
#  (486, "Chataya's brothel"),
#  (487, 'House Stark'),
#  (488, 'Walgrave'),
#  (489, 'First Flints'),
#  (490, 'House Grafton'),
#  (491, None),
#  (492, 'Merrit'),
#  (493, 'Most Devout'),
#  (494, 'House Lannister'),
#  (495, 'House Clegane'),
#  (496, 'House Targaryen'),
#  (497, 'Kingsguard'),
#  (498, "R'hllor"),
#  (499, 'Citadel'),
#  (500, "R'hllor"),
#  (501, 'House Byrch'),
#  (502, 'House Payne'),
#  (503, 'House Stark'),
#  (504, "Night's Watch"),
#  (505, 'House Velaryon'),
#  (506, 'House Blackwood'),
#  (507, 'House Stokeworth'),
#  (508, "King's Landing"),
#  (509, 'House Stark'),
#  (510, 'House Stark'),
#  (511, "Night's Watch"),
#  (512, 'StormcrowsHouse Targaryen'),
#  (513, 'House Florent'),
#  (514, "Night's Watch"),
#  (515, 'Windblown'),
#  (516, None),
#  (517, 'Dyre Den'),
#  (518, 'House Tarly'),
#  (519, "Night's Watch"),
#  (520, 'House Smallwood'),
#  (521, 'House Prester'),
#  (522, 'House Targaryen'),
#  (523, "Night's Watch"),
#  (524, None),
#  (525, 'House Waynwood'),
#  (526, "Chataya's brothel"),
#  (527, None),
#  (528, 'House Martell'),
#  (529, 'House Harlaw'),
#  (530, 'House Stark'),
#  (531, None),
#  (532, 'House Whent'),
#  (533, 'Great MastersBrazen'),
#  (534, 'Lords Declarant'),
#  (535, None),
#  (536, 'Kingsguard'),
#  (537, 'House Swyft'),
#  (538, 'House Arryn'),
#  (539, 'House TargaryenHouse'),
#  (540, "Night's Watch"),
#  (541, None),
#  (542, 'House Umber'),
#  (543, 'House Glover'),
#  (544, "Night's Watch"),
#  (545, 'House Merlyn'),
#  (546, 'Windblown'),
#  (547, 'House Frey'),
#  (548, "King's men"),
#  (549, 'House Stark'),
#  (550, None),
#  (551, 'House Paege'),
#  (552, 'House Arryn'),
#  (553, 'Brotherhood without'),
#  (554, None),
#  (555, "Night's Watch"),
#  (556, 'House Dustin'),
#  (557, 'House Frey'),
#  (558, 'House YronwoodWindblown'),
#  (559, None),
#  (560, 'House Tyrell'),
#  (561, 'Daughter'),
#  (562, 'House Targaryen'),
#  (563, 'Steelskin'),
#  (564, "Night's Watch"),
#  (565, None),
#  (566, 'Holy Hundred'),
#  (567, 'House Turnberry'),
#  (568, 'House Manderly'),
#  (569, "Night's Watch"),
#  (570, 'House Westerling'),
#  (571, None),
#  (572, None),
#  (573, 'House Payne'),
#  (574, 'House Greyjoy'),
#  (575, 'Dragonstone'),
#  (576, 'House Waynwood'),
#  (577, 'House Stark'),
#  (578, 'Most Devout'),
#  (579, 'Stormcrows'),
#  (580, None),
#  (581, None),
#  (582, None),
#  (583, 'House Martell'),
#  (584, 'House MartellWindblown'),
#  (585, "Night's Watch"),
#  (586, 'House Clifton'),
#  (587, 'House Marbrand'),
#  (588, 'House of'),
#  (589, None),
#  (590, "Night's Watch"),
#  (591, 'House Botley'),
#  (592, 'Brotherhood without'),
#  (593, 'House Thenn'),
#  (594, None),
#  (595, 'House Bracken'),
#  (596, 'Rainbow Guard'),
#  (597, 'Second Sons'),
#  (598, 'YunkaiHouse of'),
#  (599, None),
#  (600, 'House Targaryen'),
#  (601, 'House Kettleblack'),
#  (602, 'House Stark'),
#  (603, 'House Martell'),
#  (604, 'Dragonstone'),
#  (605, 'the Peach'),
#  (606, None),
#  (607, None),
#  (608, 'House Lannister'),
#  (609, None),
#  (610, None),
#  (611, 'Brave Companions'),
#  (612, 'House Reed'),
#  (613, 'Septon'),
#  (614, 'House Stark'),
#  (615, 'House Lynderly'),
#  (616, 'House Lannister'),
#  (617, 'House Martell'),
#  (618, "Night's Watch"),
#  (619, 'Gates of'),
#  (620, 'House Targaryen'),
#  (621, 'House Targaryen'),
#  (622, 'Camarron'),
#  (623, 'House Tully'),
#  (624, 'Gates of'),
#  (625, 'House Mormont'),
#  (626, 'House Stonehouse'),
#  (627, None),
#  (628, None),
#  (629, None),
#  (630, 'House Swyft'),
#  (631, 'Myraham'),
#  (632, 'House Tyrell'),
#  (633, None),
#  (634, 'QueensguardRuling council'),
#  (635, 'House Stark'),
#  (636, 'House Allyrion'),
#  (637, None),
#  (638, 'House Targaryen'),
#  (639, 'Golden Company'),
#  (640, 'House Tyrell'),
#  (641, "King's Landing"),
#  (642, 'House Stark'),
#  (643, 'House Tyrell'),
#  (644, None),
#  (645, None),
#  (646, 'House Seaworth'),
#  (647, 'House Piper'),
#  (648, 'Windblown'),
#  (649, None),
#  (650, "Alchemists' Guild"),
#  (651, 'House Stark'),
#  (652, 'House Lannister'),
#  (653, None),
#  (654, None),
#  (655, "Night's Watch"),
#  (656, 'House Targaryen'),
#  (657, 'House Lannister'),
#  (658, 'House Lannister'),
#  (659, None),
#  (660, 'House Lannister'),
#  (661, None),
#  (662, 'House Baelish'),
#  (663, 'House ArrynHouse'),
#  (664, 'Second Sons'),
#  (665, 'House Cerwyn'),
#  (666, 'Black Ears'),
#  (667, 'Nurse'),
#  (668, 'House Stark'),
#  (669, 'Kingsguard'),
#  (670, 'Second Sons'),
#  (671, "Night's Watch"),
#  (672, 'House Martell'),
#  (673, 'House Stark'),
#  (674, 'Citadel'),
#  (675, 'House Stark'),
#  (676, 'House Stark'),
#  (677, None),
#  (678, None),
#  (679, None),
#  (680, 'House Arryn'),
#  (681, None),
#  (682, 'House Stark'),
#  (683, 'House of'),
#  (684, 'House Glover'),
#  (685, 'House Estermont'),
#  (686, None),
#  (687, 'House Baratheon'),
#  (688, 'the Thirteen'),
#  (689, 'House Tyrell'),
#  (690, "Night's Watch"),
#  (691, 'Braavos'),
#  (692, 'House Caswell'),
#  (693, None),
#  (694, 'House Hornwood'),
#  (695, 'House Crabb'),
#  (696, 'House Clegane'),
#  (697, 'Stormcrows'),
#  (698, "Night's Watch"),
#  (699, 'Second Sons'),
#  (700, 'House Frey'),
#  (701, 'House Stark'),
#  (702, None),
#  (703, 'House Stark'),
#  (704, "Night's Watch"),
#  (705, 'Rainbow Guard'),
#  (706, 'Mance Rayder'),
#  (707, 'House Frey'),
#  (708, 'House Dayne'),
#  (709, None),
#  (710, 'House Greyjoy'),
#  (711, 'House Greyjoy'),
#  (712, 'Golden Company'),
#  (713, 'Sevenstreams'),
#  (714, None),
#  (715, "Night's Watch"),
#  (716, 'House Westerling'),
#  (717, 'House Stark'),
#  (718, 'House Dustin'),
#  (719, 'House Frey'),
#  (720, 'Khrazz'),
#  (721, 'Harrenhal'),
#  (722, 'Undying Ones'),
#  (723, 'House Reed'),
#  (724, 'House Karstark'),
#  (725, None),
#  (726, 'Stone Crows'),
#  (727, "Night's Watch"),
#  (728, None),
#  (729, 'House Velaryon'),
#  (730, 'Faceless Men'),
#  (731, 'House Stark'),
#  (732, 'House Karstark'),
#  (733, 'House Martell'),
#  (734, None),
#  (735, 'House Byrch'),
#  (736, 'Drowned men'),
#  (737, None),
#  (738, 'Banners'),
#  (739, "Night's Watch"),
#  (740, 'House Clegane'),
#  (741, 'Windblown'),
#  (742, 'House Darklyn'),
#  (743, 'House Sparr'),
#  (744, 'Gendry'),
#  (745, 'House Spicer'),
#  (746, 'House Greyjoy'),
#  (747, None),
#  (748, 'Second Sons'),
#  (749, 'House Stark'),
#  (750, 'House Lannister'),
#  (751, None),
#  (752, 'House Lannister'),
#  (753, None),
#  (754, 'Harlaw Hall'),
#  (755, 'House Connington'),
#  (756, 'House Ironmaker'),
#  (757, 'House Martell'),
#  (758, 'House Lannister'),
#  (759, 'House Martell'),
#  (760, None),
#  (761, 'House Frey'),
#  (762, 'House Stokeworth'),
#  (763, "Widow's Watch"),
#  (764, 'Dragonstone'),
#  (765, 'Kingsguard'),
#  (766, "Night's Watch"),
#  (767, "Night's Watch"),
#  (768, 'House Frey'),
#  (769, 'three-eyed crow'),
#  (770, 'House Tyrell'),
#  (771, 'House Frey'),
#  (772, 'House Oakheart'),
#  (773, 'House Blacktyde'),
#  (774, 'Belaquo'),
#  (775, 'House Lannister'),
#  (776, 'House Stark'),
#  (777, 'House Tallhart'),
#  (778, 'House Targaryen'),
#  (779, 'House Fowler'),
#  (780, 'House Baratheon'),
#  (781, 'House Merryweather'),
#  (782, None),
#  (783, None),
#  (784, None),
#  (785, 'Ezzara'),
#  (786, None),
#  (787, 'House Piper'),
#  (788, 'Moon Brothers'),
#  (789, 'LannisportMaesters of'),
#  (790, 'House Ryswell'),
#  (791, None),
#  (792, 'Casterly RockHouse'),
#  (793, None),
#  (794, 'Brave Companions'),
#  (795, 'House Stark')]

# %%
ix = [n for n, v in enumerate(chars_by_houses) if v == None]

# %%
missed = [ppl[i] for i in ix]

# %%
missed
# Out:
# ['Galyeon_of_Cuy',
#  'Pate_(Old)',
#  'Orell',
#  'Mance_Rayder',
#  'Ysilla',
#  'Haggon',
#  'Ternesio_Terys',
#  'Cleon',
#  'Rowan',
#  'Lommy_Greenhands',
#  'Sweets',
#  'Symon_Silver_Tongue',
#  'Torgon_Greyiron',
#  'Craster',
#  'Chayle',
#  'Haggo',
#  'Bael_the_Bard',
#  'Armen',
#  'Narbert',
#  'Rattleshirt',
#  'Hot_Pie',
#  'Jommo',
#  'Squirrel',
#  'Varamyr',
#  'Tobho_Mott',
#  'Illyrio_Mopatis',
#  'Euron_Greyjoy',
#  'Harma',
#  'Mirri_Maz_Duur',
#  'Denyo_Terys',
#  'Rolfe_the_Dwarf',
#  'Dalla',
#  'Quaithe',
#  'Fogo',
#  'Vyman',
#  'Praed',
#  'Brea',
#  'Varys',
#  'Gilly',
#  'Frenya',
#  'Qavo_Nogarys',
#  'Murch',
#  'Miklaz',
#  'Brusco',
#  'Jarl',
#  'Dryn',
#  'Bellegere_Otherys',
#  'Zei',
#  'Balon_Greyjoy',
#  'Ghael',
#  'Lorren',
#  'Grigg',
#  'Qarl_the_Maid',
#  'Weeper',
#  'Mycah',
#  'Errok',
#  'Garin_(orphan)',
#  'Jonquil',
#  'Frenken',
#  'Shae',
#  'Joramun',
#  'Tarber',
#  'Hali',
#  'Marwyn',
#  'Tormund',
#  'Rugen',
#  'Munda',
#  'Mollander',
#  'Florian_the_Fool',
#  'Mag_Mar_Tun_Doh_Weg',
#  'Arson',
#  'Harren_Hoare',
#  'Tysha',
#  'Gorne',
#  'Cressen',
#  'Val',
#  'Kedry',
#  'Gendel',
#  'Woth',
#  'Harl',
#  'Scar',
#  'Eroeh',
#  'Koss',
#  'Rosey',
#  'Weasel',
#  'Joss',
#  'Ralf_(Limper)',
#  'Drogo',
#  'Quaro',
#  'Bump',
#  'Kojja_Mo',
#  'Husband',
#  'Qotho',
#  'Spotted_Cat',
#  'Creighton_Longbough',
#  'Cromm',
#  'Quhuru_Mo',
#  'Talea',
#  'Kurz',
#  'Draqaz',
#  'Murenmure',
#  'Theobald',
#  'Ragwyle',
#  'Chiggen',
#  'Hizdahr_zo_Loraq',
#  'Toregg',
#  'Illifer',
#  'Pono',
#  'Khorane_Sathmantes',
#  'Holly',
#  'Azor_Ahai',
#  'Soren_Shieldbreaker',
#  'Thistle',
#  'Moreo_Tumitis',
#  'Marillion',
#  'Grimtongue',
#  'Barsena',
#  'Ogo',
#  'Raymun_Redbeard',
#  'Xhondo',
#  'Tristifer_IV_Mudd',
#  'Dobber',
#  'Mebble',
#  'Red_Oarsman',
#  'Torwold_Browntooth',
#  'Roone',
#  'Quill',
#  'Ryk',
#  'Cutjack',
#  'Wun_Weg_Wun_Dar_Wun',
#  'Larraq',
#  'Hagen',
#  'Big_Boil',
#  'Yorko_Terys',
#  'Morgo',
#  'Sharna']

# %%
c_by_h = dict(zip(ppl, chars_by_houses))

# %%
c_by_h
# Out:
# {'Addam_Marbrand': 'House Marbrand',
#  'Aegon_Frey_(son_of_Stevron)': 'House Frey',
#  'Aegon_I_Targaryen': 'House Targaryen',
#  'Aegon_Targaryen_(son_of_Rhaegar)': 'House Targaryen',
#  'Aegon_V_Targaryen': 'House Targaryen',
#  'Aemon_Targaryen_(Dragonknight)': 'Targaryen',
#  'Aemon_Targaryen_(Maester_Aemon)': 'Targaryen',
#  'Aenys_Frey': 'House Frey',
#  'Aeron_Greyjoy': 'Drowned men',
#  'Aerys_II_Targaryen': 'House Targaryen',
#  'Aerys_I_Targaryen': 'House Targaryen',
#  'Aggar': 'House Greyjoy',
#  'Aggo': 'House Targaryen',
#  'Alayaya': "Chataya's brothel",
#  'Albett': "Night's Watch",
#  'Alebelly': 'House Stark',
#  'Alerie_Hightower': 'House Tyrell',
#  'Alester_Florent': 'House Florent',
#  'Alla_Tyrell': 'House Tyrell',
#  'Allar_Deem': 'City Watch',
#  'Allard_Seaworth': 'House Seaworth',
#  'Alleras': 'Citadel',
#  'Alliser_Thorne': "Night's Watch",
#  'Alyn': 'House Stark',
#  'Alys_Arryn': 'House Waynwood',
#  'Alys_Karstark': 'House Thenn',
#  'Alysane_Mormont': 'House Mormont',
#  'Amabel': 'House Whent',
#  'Amerei_Frey': 'House Lannister',
#  'Amory_Lorch': 'House Lannister',
#  'Anders_Yronwood': 'House Yronwood',
#  'Andrew_Estermont': 'House Baratheon',
#  'Andrey_Dalt': 'House Dalt',
#  'Anguy': 'Anguy',
#  'Anya_Waynwood': 'Lords Declarant',
#  'Archibald_Yronwood': 'House YronwoodWindblown',
#  'Ardrian_Celtigar': 'House Celtigar',
#  'Areo_Hotah': 'House Martell',
#  'Arianne_Martell': 'House Martell',
#  'Armen': None,
#  'Arnolf_Karstark': 'House Karstark',
#  'Aron_Santagar': 'House Baratheon',
#  'Arron': "Night's Watch",
#  'Arson': None,
#  'Arstan': 'House TargaryenHouse',
#  'Arthor_Karstark': 'House Karstark',
#  'Arthur_Dayne': 'Kingsguard',
#  'Arwyn_Oakheart': 'House Oakheart',
#  'Arya_Stark': 'House Stark',
#  'Arys_Oakheart': 'Kingsguard',
#  'Asha_Greyjoy': 'House Ironmaker',
#  'Ashara_Dayne': 'House Dayne',
#  'Aurane_Waters': 'House Velaryon',
#  'Axell_Florent': "Queen's men",
#  'Azor_Ahai': None,
#  'Bael_the_Bard': None,
#  'Baelor_Blacktyde': 'House Blacktyde',
#  'Baelor_I_Targaryen': 'House Targaryen',
#  'Ballabar': 'House Redwyne',
#  'Balman_Byrch': 'House Byrch',
#  'Balon_Greyjoy': None,
#  'Balon_Swann': 'Kingsguard',
#  'Bannen': "Night's Watch",
#  'Barbrey_Dustin': 'House Dustin',
#  'Barristan_Selmy': 'House TargaryenHouse',
#  'Barsena': None,
#  'Bartimus': 'House Manderly',
#  'Bedwyck': "Night's Watch",
#  'Belaquo': 'Belaquo',
#  'Bellegere_Otherys': None,
#  'Belwas': 'QueensguardRuling council',
#  'Ben_Bones': 'House Bolton',
#  'Ben_Plumm': 'Second Sons',
#  'Benedar_Belmore': 'Lords Declarant',
#  'Benerro': "R'hllor",
#  'Benethon_Scales': "DragonstoneQueen's men",
#  'Benfred_Tallhart': 'House Tallhart',
#  'Benjen_Stark': 'House Stark',
#  'Beric_Dondarrion': 'Brotherhood without',
#  'Beth_Cassel': 'House Cassel',
#  'Big_Boil': None,
#  'Biter': 'Brave Companions',
#  'Black_Balaq': 'Golden Company',
#  'Blane': "Night's Watch",
#  'Bloodbeard': 'Bloodbeard',
#  'Blue_Bard': 'House Tyrell',
#  'Bonifer_Hasty': 'Holy Hundred',
#  'Boros_Blount': 'Kingsguard',
#  'Bowen_Marsh': "Night's Watch",
#  'Bran_Stark': 'House Stark',
#  'Brandon_Norrey': 'House Norrey',
#  'Brandon_Stark': 'House Stark',
#  'Brea': None,
#  'Brella': 'House Lannister',
#  'Brenett': 'House Frey',
#  'Brienne_of_Tarth': 'House Baratheon',
#  'Bronn': 'House Stokeworth',
#  'Brus_Buckler': 'Baratheon of',
#  'Brusco': None,
#  'Bryce_Caron': 'Rainbow Guard',
#  'Brynden_Rivers': "Night's Watch",
#  'Brynden_Tully': 'House StarkHouse',
#  'Bump': None,
#  'Butterbumps': 'House Tyrell',
#  'Byam_Flint': "Night's Watch",
#  'Caggo': 'Windblown',
#  'Caleotte': 'House Martell',
#  'Camarron': 'Camarron',
#  'Captain_Myraham': 'Myraham',
#  'Captain_Myraham_Daughter': 'Daughter',
#  'Catelyn_Stark': 'House Stark',
#  'Cayn': 'House Stark',
#  'Cedra': 'House Martell',
#  'Cedric_Payne': 'House Payne',
#  'Cellador': "Night's Watch",
#  'Cersei_Lannister': 'House Lannister',
#  'Chataya': "Chataya's brothel",
#  'Chayle': None,
#  'Chella': 'Black Ears',
#  'Chett': "Night's Watch",
#  'Chiggen': None,
#  'Chiswyck': 'House Clegane',
#  'Clarence_Crabb': 'House Crabb',
#  'Clayton_Suggs': 'House Baratheon',
#  'Clement_Piper': 'House Piper',
#  'Cleon': None,
#  'Cleos_Frey': 'House Lannister',
#  'Cletus_Yronwood': 'House Yronwood',
#  'Cley_Cerwyn': 'House Cerwyn',
#  'Clubfoot_Karl': "Night's Watch",
#  'Clydas': "Night's Watch",
#  'Cohollo': 'Khal Drogo',
#  'Coldhands': 'three-eyed crow',
#  'Colemon': 'House Arryn',
#  'Colen_of_Greenpools': 'House Baratheon',
#  'Conn': 'Stone Crows',
#  'Coratt': 'Stone Crows',
#  'Corliss_Penny': 'House Baratheon',
#  'Cortnay_Penrose': 'House Baratheon',
#  'Cotter_Pyke': "Night's Watch",
#  'Craster': None,
#  'Creighton_Longbough': None,
#  'Cressen': None,
#  'Cromm': None,
#  'Cutjack': None,
#  'Daario_Naharis': 'StormcrowsHouse Targaryen',
#  'Dacey_Mormont': 'House Mormont',
#  'Daemon_Sand': 'House Allyrion',
#  'Daenerys_Targaryen': 'House Targaryen',
#  'Daeron_II_Targaryen': 'House Targaryen',
#  'Daeron_I_Targaryen': 'House Targaryen',
#  'Dagmer': 'House Greyjoy',
#  'Dalbridge': "Night's Watch",
#  'Dalla': None,
#  'Damon_Dance_for_Me': 'Me',
#  'Dancy': "Chataya's brothel",
#  'Danwell_Frey': 'House Frey',
#  'Dareon': "Night's Watch",
#  'Daryn_Hornwood': 'House Hornwood',
#  'Daven_Lannister': 'House Lannister',
#  'Davos_Seaworth': 'House Baratheon',
#  'Denyo_Terys': None,
#  'Denys_Darklyn': 'House Darklyn',
#  'Denys_Mallister': "Night's Watch",
#  'Denzo_Dhan': 'Dhan',
#  'Desmond': 'House Stark',
#  'Desmond_Grell': "Night's Watch",
#  'Devan_Seaworth': 'House Baratheon',
#  'Dick_Crabb': 'House Crabb',
#  'Dick_Follard': "Night's Watch",
#  'Dick_Straw': 'Windblown',
#  'Dirk': "Night's Watch",
#  'Dobber': None,
#  'Dolf': 'Stone Crows',
#  'Donal_Noye': "Night's Watch",
#  'Donella_Hornwood': 'House Hornwood',
#  'Donnel_Waynwood': 'House Waynwood',
#  'Dontos_Hollard': 'House Hollard',
#  'Doran_Martell': 'Martell',
#  'Dorcas': 'House Lannister',
#  'Doreah': 'House Targaryen',
#  'Draqaz': None,
#  'Drennan': 'House Greyjoy',
#  'Drogo': None,
#  'Dryn': None,
#  'Dunsen': 'House Clegane',
#  'Dunstan_Drumm': 'House Drumm',
#  'Dywen': "Night's Watch",
#  'Ebben': "Night's Watch",
#  'Eddard_Stark': 'House Stark',
#  'Eddison_Tollett': "Night's Watch",
#  'Edmure_Tully': 'House Tully',
#  'Edric_Storm': 'House Baratheon',
#  'Edwyn_Frey': 'House Frey',
#  'Elbert_Arryn': 'House Arryn',
#  'Elder_Brother': 'Brother',
#  'Eldon_Estermont': 'House Estermont',
#  'Elia_Martell': 'House Targaryen',
#  'Elinor_Tyrell': 'House Tyrell',
#  'Ellaria_Sand': 'House Martell',
#  'Elmar_Frey': 'House Frey',
#  'Elys_Waynwood': 'House Waynwood',
#  'Emmett': "Night's Watch",
#  'Emmon_Cuy': 'Rainbow Guard',
#  'Emmon_Frey': 'House Frey',
#  'Emmond': 'Drowned men',
#  'Emrick': "Night's Watch",
#  'Eon_Hunter': 'House Hunter',
#  'Eroeh': None,
#  'Errok': None,
#  'Euron_Greyjoy': None,
#  'Eustace_Brune': 'Dyre Den',
#  'Ezzara': 'Ezzara',
#  'Falyse_Stokeworth': 'House Byrch',
#  'Farlen': 'House Stark',
#  'Florian_the_Fool': None,
#  'Fogo': None,
#  'Forley_Prester': 'House Prester',
#  'Franklyn_Flowers': 'Golden Company',
#  'Franklyn_Fowler': 'House Fowler',
#  'Frenken': None,
#  'Frenya': None,
#  'Fulk': "Night's Watch",
#  'Galazza_Galare': 'Galare',
#  'Galbart_Glover': 'House Glover',
#  'Galyeon_of_Cuy': None,
#  'Gared': "Night's Watch",
#  'Garin_(orphan)': None,
#  'Gariss': 'House Stark',
#  'Garlan_Tyrell': 'Brightwater Keep',
#  'Garrett_Paege': 'House Paege',
#  'Garth_(Wolfs_Den)': 'Garth',
#  'Garth_Greyfeather': "Night's Watch",
#  'Garth_Tyrell': 'House Tyrell',
#  'Gawen_Westerling': 'House Westerling',
#  'Gelmarr': 'House Greyjoy',
#  'Gendel': None,
#  'Gendry': 'Gendry',
#  'Genna_Lannister': 'House Frey',
#  'Gerald_Gower': "King's men",
#  'Gerold_Dayne': 'High Hermitage',
#  'Gerold_Grafton': 'House Grafton',
#  'Gerold_Hightower': 'Kingsguard',
#  'Gerrick_Kingsblood': 'House Redbeard',
#  'Gerris_Drinkwater': 'House YronwoodWindblown',
#  'Ghael': None,
#  'Gilly': None,
#  'Gilwood_Hunter': 'House Hunter',
#  'Godric_Borrell': 'House Borrell',
#  'Godry_Farring': 'House Baratheon',
#  'Goghor_the_Giant': 'Giant',
#  'Gormon_Tyrell': 'Citadel',
#  'Gormond_Goodbrother': 'House Goodbrother',
#  'Gorne': None,
#  'Gorold_Goodbrother': 'House Goodbrother',
#  'Grazdan_mo_Eraz': 'House of',
#  'Grazhar': 'Grazhar',
#  'Greenbeard': 'Greenbeard',
#  'Gregor_Clegane': 'House Lannister',
#  'Grenn': "Night's Watch",
#  'Gretchel': 'House Arryn',
#  'Grey_Worm': 'UnsulliedHouse Targaryen',
#  'Greydon_Goodbrother': 'House Goodbrother',
#  'Grigg': None,
#  'Grimtongue': None,
#  'Grisel': 'House Baelish',
#  'Groleo': 'House Targaryen',
#  'Grunt': 'House Bolton',
#  'Guncer_Sunglass': 'House Sunglass',
#  'Gunthor_son_of_Gurn': 'Stone Crows',
#  'Guyard_Morrigen': 'Rainbow Guard',
#  'Gyles_Grafton': 'House Grafton',
#  'Gyles_Rosby': 'House Rosby',
#  'Gynir': 'House Greyjoy',
#  'Hagen': None,
#  'Haggo': None,
#  'Haggon': None,
#  'Hairy_Hal': "Night's Watch",
#  'Hake': "Night's Watch",
#  'Halder': "Night's Watch",
#  'Haldon': 'House Targaryen',
#  'Hali': None,
#  'Hallis_Mollen': 'House Stark',
#  'Hallyne': "Alchemists' Guild",
#  'Halys_Hornwood': 'House Hornwood',
#  'Hareth_(Moles_Town)': 'Hareth',
#  'Harl': None,
#  'Harma': None,
#  'Harra': 'House Lannister',
#  'Harras_Harlaw': 'Grey Garden',
#  'Harren_Hoare': None,
#  'Harrold_Hardyng': 'House Arryn',
#  'Harry_Strickland': 'Golden Company',
#  'Harwin': 'Brotherhood without',
#  'Harwood_Stout': 'House Dustin',
#  'Harys_Swyft': 'House Swyft',
#  'Hayhead': 'House Stark',
#  'Helman_Tallhart': 'House Tallhart',
#  'Hero': 'Unsullied',
#  'Heward': 'House Stark',
#  'High_Septon_(Tyrions)': 'Septon',
#  'High_Septon_(fat_one)': 'Septon',
#  'High_Sparrow': 'SparrowsFaith Militant',
#  'Hizdahr_zo_Loraq': None,
#  'Hobb': "Night's Watch",
#  'Hobber_Redwyne': 'House Redwyne',
#  'Hodor': 'House Stark',
#  'Holly': None,
#  'Hop_Robin': 'Robin',
#  'Horas_Redwyne': 'House Redwyne',
#  'Horton_Redfort': 'Lords Declarant',
#  'Hosteen_Frey': 'House Frey',
#  'Hoster_Blackwood': 'House Blackwood',
#  'Hoster_Tully': 'House Tully',
#  'Hot_Pie': None,
#  'Hother_Umber': 'House Umber',
#  'Hotho_Harlaw': 'Tower of',
#  'Howland_Reed': 'House Reed',
#  'Hugh': 'House Arryn',
#  'Hugh_Hungerford': 'Windblown',
#  'Hugo_Vance': 'Atranta',
#  'Hullen': 'House Stark',
#  'Humfrey_Hewett': 'House Hewett',
#  'Husband': None,
#  'Hyle_Hunt': 'House Tarly',
#  'Illifer': None,
#  'Illyrio_Mopatis': None,
#  'Ilyn_Payne': 'House Payne',
#  'Imry_Florent': 'House Florent',
#  'Irri': 'House Targaryen',
#  'Jacelyn_Bywater': 'City Watch',
#  'Jack_Be_Lucky': 'Lucky',
#  'Jack_Bulwer': "Night's Watch",
#  'Jacks': 'House Stark',
#  'Jaehaerys_I_Targaryen': 'House Targaryen',
#  'Jafer_Flowers': "Night's Watch",
#  'Jaime_Lannister': 'Kingsguard',
#  'Jalabhar_Xho': 'Summer Islands',
#  'Janos_Slynt': 'City Watch',
#  'Jaqen_Hghar': 'Hghar',
#  'Jared_Frey': 'House Frey',
#  'Jaremy_Rykker': "Night's Watch",
#  'Jarl': None,
#  'Jarman_Buckwell': "Night's Watch",
#  'Jason_Mallister': 'House Mallister',
#  'Jeor_Mormont': "Night's Watch",
#  'Jeyne_Farman': 'House Clifton',
#  'Jeyne_Heddle': 'Banners',
#  'Jeyne_Poole': 'House Poole',
#  'Jeyne_Westerling': 'House Stark',
#  'Jhiqui': 'House Targaryen',
#  'Jhogo': 'House Targaryen',
#  'Joanna_Lannister': 'House Lannister',
#  'Jocelyn_Swyft': 'House Swyft',
#  'Joffrey_Baratheon': 'House Baratheon',
#  'Jojen_Reed': 'House Reed',
#  'Jommo': None,
#  'Jon_Arryn': 'House Arryn',
#  'Jon_Connington': 'House TargaryenGolden',
#  'Jon_Fossoway': 'New Barrel',
#  'Jon_Snow': "Night's Watch",
#  'Jon_Umber_(Greatjon)': 'House Umber',
#  'Jon_Umber_(Smalljon)': 'House Umber',
#  'Jonos_Bracken': 'House Bracken',
#  'Jonothor_Darry': 'Kingsguard',
#  'Jonquil': None,
#  'Jorah_Mormont': 'House TargaryenSecond',
#  'Joramun': None,
#  'Jory_Cassel': 'House Cassel',
#  'Joseth': 'House Stark',
#  'Josmyn_Peckledon': 'House Peckledon',
#  'Joss': None,
#  'Joy_Hill': 'House Lannister',
#  'Justin_Massey': 'House Baratheon',
#  'Jyck': 'House Lannister',
#  'Karyl_Vance': "Wayfarer's Rest",
#  'Kasporio': 'Second Sons',
#  'Kedry': None,
#  'Kegs': "Night's Watch",
#  'Kella': 'House Baelish',
#  'Kerwin': 'House Greyjoy',
#  'Kevan_Lannister': 'House Lannister',
#  'Khorane_Sathmantes': None,
#  'Khrazz': 'Khrazz',
#  'Kindly_Man': 'Faceless Men',
#  'Kojja_Mo': None,
#  'Koss': None,
#  'Kraznys_mo_Nakloz': 'House of',
#  'Kurleket': 'House Bracken',
#  'Kurz': None,
#  'Kyra': 'House Stark',
#  'Lambert_Turnberry': 'House Turnberry',
#  'Lamprey': 'Dragonstone',
#  'Lancel_Lannister': 'Casterly RockHouse',
#  'Lanna_(Happy_Port)': 'Happy Port',
#  'Lark': "Night's Watch",
#  'Larraq': None,
#  'Leaf': 'last greenseer',
#  'Leathers': "Night's Watch",
#  'Lem': 'Lem',
#  'Lemore': 'House Targaryen',
#  'Leo_Lefford': 'House Lefford',
#  'Leo_Tyrell': 'Tyrell',
#  'Leobald_Tallhart': 'House Tallhart',
#  'Leona_Woolfield': 'House Manderly',
#  'Leonette_Fossoway': 'House Tyrell',
#  'Lewyn_Martell': 'Kingsguard',
#  'Lewys_Piper': 'House Piper',
#  'Lollys_Stokeworth': 'House Stokeworth',
#  'Lommy_Greenhands': None,
#  'Longwater_Pyke': 'House Greyjoy',
#  'Loras_Tyrell': 'Kingsguard',
#  'Lorent_Caswell': 'House Caswell',
#  'Lorren': None,
#  'Lothar_Frey': 'House Frey',
#  'Lothor_Brune': 'BrownhollowHouse Baelish',
#  'Lucas_Codd': 'House Codd',
#  'Lucifer_Long': 'Windblown',
#  'Luton': 'House Bolton',
#  'Luwin': 'House Stark',
#  'Lyanna_Mormont': 'House Mormont',
#  'Lyanna_Stark': 'House Stark',
#  'Lyle_Crakehall': 'House Crakehall',
#  'Lyn_Corbray': 'Lords Declarant',
#  'Lynesse_Hightower': 'House Mormont',
#  'Lyonel_Corbray': 'House Corbray',
#  'Lysa_Arryn': 'House ArrynHouse',
#  'Lysono_Maar': 'Golden Company',
#  'Mace_Tyrell': 'House Tyrell',
#  'Mad_Huntsman': 'Huntsman',
#  'Maddy': 'House Arryn',
#  'Maege_Mormont': 'House Mormont',
#  'Maegor_I_Targaryen': 'House Targaryen',
#  'Maekar_I_Targaryen': 'House Targaryen',
#  'Mag_Mar_Tun_Doh_Weg': None,
#  'Maggy': 'House Spicer',
#  'Malaquo_Maegyr': 'iger',
#  'Malegorn': "DragonstoneQueen's men",
#  'Mallador_Locke': "Night's Watch",
#  'Mance_Rayder': None,
#  'Mandon_Moore': 'Kingsguard',
#  'Manfrey_Martell': 'House Martell',
#  'Margaery_Tyrell': 'House Tyrell',
#  'Marghaz_zo_Loraq': 'Great MastersBrazen',
#  'Marillion': None,
#  'Mariya_Darry': 'House Frey',
#  'Mark_Mullendore': 'House Mullendore',
#  'Marlon_Manderly': 'House Manderly',
#  'Maron_Greyjoy': 'House Greyjoy',
#  'Marq_Piper': 'House Piper',
#  'Marselen': "Mother's Men",
#  'Martyn_Lannister': 'House Lannister',
#  'Martyn_Rivers': 'House Frey',
#  'Marwyn': None,
#  'Marya_Seaworth': 'House Seaworth',
#  'Masha_Heddle': 'House Heddle',
#  'Mathis_Rowan': 'House Rowan',
#  'Matthar': "Night's Watch",
#  'Matthos_Seaworth': 'House Seaworth',
#  'Mebble': None,
#  'Meera_Reed': 'House Reed',
#  'Megga_Tyrell': 'House Tyrell',
#  'Melara_Hetherspoon': 'House Hetherspoon',
#  'Meldred_Merlyn': 'House Merlyn',
#  'Melisandre': 'Melisandre',
#  'Mellei': 'House Martell',
#  'Meralyn': 'Happy Port',
#  'Meribald': 'Meribald',
#  'Meris': 'Windblown',
#  'Mero': 'Second Sons',
#  'Merrett_Frey': 'House Frey',
#  'Merrit': 'Merrit',
#  'Meryn_Trant': 'Kingsguard',
#  'Mezzara': 'Mezzara',
#  'Mikken': 'House Stark',
#  'Miklaz': None,
#  'Mirri_Maz_Duur': None,
#  'Missandei': 'House Targaryen',
#  'Moelle': 'Most Devout',
#  'Mollander': None,
#  'Monford_Velaryon': 'House Velaryon',
#  'Moon_Boy': "King's Landing",
#  'Moqorro': "R'hllor",
#  'Mord': 'House Arryn',
#  'Mordane': 'House Stark',
#  'Moreo_Tumitis': None,
#  'Morgo': None,
#  'Morra': 'House Martell',
#  'Morrec': 'House Lannister',
#  'Mors_Umber': 'House Umber',
#  'Mully': "Night's Watch",
#  'Munda': None,
#  'Murch': None,
#  'Murenmure': None,
#  'Mya_Stone': 'Gates of',
#  'Mycah': None,
#  'Mychel_Redfort': 'House Redfort',
#  'Myles_Toyne': 'Golden Company',
#  'Myranda_Royce': 'Gates of',
#  'Myrcella_Baratheon': 'House Baratheon',
#  'Nage': 'House Bolton',
#  'Nan': 'House Stark',
#  'Narbert': None,
#  'Narbert_Grandison': "Queen's men",
#  'Nestor_Royce': 'Gates of',
#  'Nurse': 'Nurse',
#  'Nute': 'House Greyjoy',
#  'Nyessos_Vhassar': 'Elephants',
#  'Nymeria_Sand': 'House Martell',
#  'Obara_Sand': 'House Martell',
#  'Oberyn_Martell': 'Second Sons',
#  'Ogo': None,
#  'Old_Bill_Bone': 'Windblown',
#  'Olenna_Redwyne': 'House Tyrell',
#  'Olyvar_Frey': 'House Frey',
#  'Orell': None,
#  'Orton_Merryweather': 'House Merryweather',
#  'Osfryd_Kettleblack': 'City Watch',
#  'Osha': 'House Stark',
#  'Osmund_Kettleblack': 'Kingsguard',
#  'Osney_Kettleblack': 'House Kettleblack',
#  'Oswell_Kettleblack': 'House Baelish',
#  'Oswell_Whent': 'Kingsguard',
#  'Othell_Yarwyck': "Night's Watch",
#  'Othor': "Night's Watch",
#  'Ottyn_Wythers': "Night's Watch",
#  'Owen': 'Owen',
#  'Owen_Merryweather': 'House Merryweather',
#  'Oznak_zo_Pahl': 'Great Masters',
#  'Palla': 'House Stark',
#  'Patchface': 'Dragonstone',
#  'Pate_(Old)': None,
#  'Pate_(novice)': 'Citadel',
#  'Pate_(whipping_boy)': "King's Landing",
#  'Patrek_of_Kings_Mountain': 'Mountain',
#  'Paxter_Redwyne': 'House Redwyne',
#  'Penny': 'Second Sons',
#  'Perwyn_Frey': 'House Frey',
#  'Petyr_Baelish': 'FingersHouse Baelish',
#  'Petyr_Frey': 'House Frey',
#  'Pia': 'House Whent',
#  'Podrick_Payne': 'House Payne',
#  'Polliver': 'House Clegane',
#  'Pono': None,
#  'Porridge': 'Dragonstone',
#  'Porther': 'House Stark',
#  'Poxy_Tym': 'House Stark',
#  'Praed': None,
#  'Prendahl_na_Ghezn': 'Stormcrows',
#  'Preston_Greenfield': 'Kingsguard',
#  'Puckens': 'House Lannister',
#  'Pyat_Pree': 'Undying Ones',
#  'Pycelle': 'House Lannister',
#  'Pyg': 'Brave Companions',
#  'Pylos': 'Dragonstone',
#  'Pypar': "Night's Watch",
#  'Qarl_the_Maid': None,
#  'Qavo_Nogarys': None,
#  'Qezza': 'Qezza',
#  'Qhorin_Halfhand': "Night's Watch",
#  'Qotho': None,
#  'Quaithe': None,
#  'Quaro': None,
#  'Quellon_Greyjoy': 'House Greyjoy',
#  'Quentyn_Martell': 'House MartellWindblown',
#  'Quhuru_Mo': None,
#  'Quill': None,
#  'Qyburn': 'House Lannister',
#  'Rafford': 'House Clegane',
#  'Ragwyle': None,
#  'Rakharo': 'House Targaryen',
#  'Ralf_(Limper)': None,
#  'Ralf_Stonehouse': 'House Stonehouse',
#  'Ramsay_Snow': 'DreadfortHouse Bolton',
#  'Randyll_Tarly': 'House Tarly',
#  'Rast': "Night's Watch",
#  'Rattleshirt': None,
#  'Ravella_Swann': 'House Smallwood',
#  'Raymun_Darry': 'House Darry',
#  'Raymun_Redbeard': None,
#  'Raynald_Westerling': 'House Westerling',
#  'Raynard': 'Most Devout',
#  'Red_Oarsman': None,
#  'Reek': 'House Bolton',
#  'Renly_Baratheon': 'House Baratheon',
#  'Rennifer_Longwaters': 'House Longwaters',
#  'Reznak_mo_Reznak': 'House Targaryen',
#  'Rhaegar_Frey': 'House Frey',
#  'Rhaegar_Targaryen': 'House Targaryen',
#  'Rhaegel_Targaryen': 'House Targaryen',
#  'Rhaego': 'House Targaryen',
#  'Rhaella_Targaryen': 'House Targaryen',
#  'Rhaenys_Targaryen': 'House Targaryen',
#  'Rhaenys_Targaryen_(daughter_of_Rhaegar)': 'House Targaryen',
#  'Ricasso': 'House Martell',
#  'Richard_Horpe': 'House Baratheon',
#  'Rickard_Karstark': 'House Karstark',
#  'Rickard_Stark': 'House Stark',
#  'Rickon_Stark': 'House Stark',
#  'Robar_Royce': 'Rainbow Guard',
#  'Robb_Stark': 'House Stark',
#  'Robert_Arryn': 'House Arryn',
#  'Robert_Baratheon': 'House Baratheon',
#  'Robert_Strong': 'Kingsguard',
#  'Robett_Glover': 'House Glover',
#  'Robin_Flint': "Widow's Watch",
#  'Robin_Ryger': "House TullyNight's",
#  'Rodrik_Cassel': 'House Stark',
#  'Rodrik_Harlaw': 'House Harlaw',
#  'Rodrik_Sparr': 'House Sparr',
#  'Roger_Ryswell': 'House Ryswell',
#  'Rolfe_the_Dwarf': None,
#  'Rollam_Westerling': 'House Westerling',
#  'Rolly_Duckfield': 'Kingsguard',
#  'Rolph_Spicer': 'House Westerling',
#  'Ronnet_Connington': 'House Connington',
#  'Roone': None,
#  'Roose_Bolton': 'House Bolton',
#  'Roose_Ryswell': 'House Ryswell',
#  'Rorge': 'Brave Companions',
#  'Rory': "Night's Watch",
#  'Rosey': None,
#  'Roslin_Frey': 'House Tully',
#  'Rossart': "Alchemists' Guild",
#  'Rowan': None,
#  'Rugen': None,
#  'Rus': 'Drowned men',
#  'Ryk': None,
#  'Ryman_Frey': 'House Frey',
#  'Salladhor_Saan': 'Dragonstone',
#  'Sallor': 'Stormcrows',
#  'Samwell_Tarly': "Night's Watch",
#  'Sandor_Clegane': 'House Lannister',
#  'Sansa_Stark': 'House Stark',
#  'Sarella_Sand': 'House Martell',
#  'Satin': "Night's Watch",
#  'Sawane_Botley': 'House Botley',
#  'Scar': None,
#  'Scolera': 'Scolera',
#  'Selwyn_Tarth': 'House Tarth',
#  'Selyse_Florent': 'House Baratheon',
#  'Senelle': 'House Lannister',
#  'Shadd': 'House Stark',
#  'Shadrich': 'Harrenhal',
#  'Shae': None,
#  'Shagga': 'Stone Crows',
#  'Shagwell': 'Shagwell',
#  'Sharna': None,
#  'Shireen_Baratheon': 'House Baratheon',
#  'Shitmouth': 'House Clegane',
#  'Shortear': 'House Lannister',
#  'Shrouded_Lord': 'Stone men',
#  'Sigfryd_Harlaw': 'Harlaw Hall',
#  'Sigorn': 'nnsHouse Thenn',
#  'Simon_Toyne': 'Kingswood Brotherhood',
#  'Skahaz_mo_Kandaq': 'House TargaryenShavepatesBrazen',
#  'Skinner': 'House Bolton',
#  'Small_Paul': "Night's Watch",
#  'Smiling_Knight': 'Kingswood Brotherhood',
#  'Softfoot': "Night's Watch",
#  'Soren_Shieldbreaker': None,
#  'Sour_Alyn': 'House Bolton',
#  'Spare_Boot': "Night's Watch",
#  'Spotted_Cat': None,
#  'Squint': 'House Greyjoy',
#  'Squirrel': None,
#  'Stafford_Lannister': 'House Lannister',
#  'Stannis_Baratheon': 'House Baratheon',
#  'Steelskin': 'Steelskin',
#  'Steffon_Baratheon': 'House Baratheon',
#  'Steffon_Varner': 'House Varner',
#  'Stevron_Frey': 'House Frey',
#  'Stiv': 'Stiv',
#  'Stonesnake': "Night's Watch",
#  'Stygg': 'House Greyjoy',
#  'Styr': 'nn',
#  'Sweets': None,
#  'Sybell_Spicer': 'House Westerling',
#  'Sybelle_Glover': 'House Glover',
#  'Sylva_Santagar': 'House Estermont',
#  'Symon_Silver_Tongue': None,
#  'Symon_Stripeback': 'Free Brothers',
#  'Symond_Templeton': 'Lords Declarant',
#  'Syrio_Forel': 'House Stark',
#  'Taena_of_Myr': 'House Merryweather',
#  'Talbert_Serry': 'House Serry',
#  'Talea': None,
#  'Tallad': "King's Landing",
#  'Tanda_Stokeworth': 'House Stokeworth',
#  'Tansy': 'the Peach',
#  'Tarber': None,
#  'Tattered_Prince': "SonsIron ShieldsMaiden's",
#  'Ternesio_Terys': None,
#  'Terrance_Lynderly': 'House Lynderly',
#  'Theobald': None,
#  'Theomore': 'LannisportMaesters of',
#  'Theon_Greyjoy': 'House Greyjoy',
#  'Thistle': None,
#  'Thoren_Smallwood': "Night's Watch",
#  'Thoros_of_Myr': 'Brotherhood without',
#  'Tickler': 'House Clegane',
#  'Timeon': 'Brave Companions',
#  'Timett': 'Burned Men',
#  'Timoth': 'House Martell',
#  'Tion_Frey': 'House Lannister',
#  'Tobho_Mott': None,
#  'Todder': "Night's Watch",
#  'Tom_Barleycorn': "Night's Watch",
#  'Tom_of_Sevenstreams': 'Sevenstreams',
#  'Tomard': 'House Stark',
#  'Tommen_Baratheon': 'House Baratheon',
#  'Torbert': 'Most Devout',
#  'Toregg': None,
#  'Torghen_Flint': 'First Flints',
#  'Torgon_Greyiron': None,
#  'Tormund': None,
#  'Torrhen_Karstark': 'House Karstark',
#  'Torrhen_Stark': 'House Stark',
#  'Torwold_Browntooth': None,
#  'Tregar': 'House Lannister',
#  'Tristifer_Botley': 'House Botley',
#  'Tristifer_IV_Mudd': None,
#  'Trystane_Martell': 'House Martell',
#  'Tybero_Istarion': 'Second Sons',
#  'Tycho_Nestoris': 'Braavos',
#  'Tyene_Sand': 'House Martell',
#  'Tyrion_Lannister': 'Second Sons',
#  'Tysha': None,
#  'Tytos_Blackwood': 'House Blackwood',
#  'Tywin_Lannister': 'House Lannister',
#  'Ulf_son_of_Umar': 'Moon Brothers',
#  'Ulmer': "Night's Watch",
#  'Umma': 'White',
#  'Unella': 'Most Devout',
#  'Urswyck': 'Brave Companions',
#  'Urzen': 'House Greyjoy',
#  'Utherydes_Wayn': 'House Tully',
#  'Val': None,
#  'Varamyr': None,
#  'Vardis_Egen': 'House Arryn',
#  'Vargo_Hoat': 'Brave Companions',
#  'Varly': 'House Stark',
#  'Varys': None,
#  'Vayon_Poole': 'House Poole',
#  'Victarion_Greyjoy': 'House Greyjoy',
#  'Visenya_Targaryen': 'House Targaryen',
#  'Viserys_Targaryen': 'House Targaryen',
#  'Vylarr': 'House Lannister',
#  'Vyman': None,
#  'Waif': 'Faceless Men',
#  'Walda_Frey_(daughter_of_Merrett)': 'House Bolton',
#  'Walder_Frey': 'House Frey',
#  'Walder_Frey_(son_of_Jammos)': 'House Frey',
#  'Walder_Frey_(son_of_Merrett)': 'House Frey',
#  'Walder_Rivers': 'House Frey',
#  'Walgrave': 'Walgrave',
#  'Walton': 'House Bolton',
#  'Watt': "Night's Watch",
#  'Waymar_Royce': "Night's Watch",
#  'Weasel': None,
#  'Weeper': None,
#  'Weese': 'House Lannister',
#  'Wendel_Manderly': 'House Manderly',
#  'Werlag': 'House Greyjoy',
#  'Wex_Pyke': 'House Greyjoy',
#  'Wick_Whittlestick': "Night's Watch",
#  'Widower': 'Stormcrows',
#  'Will_(prologue)': 'Will',
#  'Willam_Dustin': 'House Dustin',
#  'Willas_Tyrell': 'House Tyrell',
#  'Willem_Lannister': 'House Lannister',
#  'William_Foxglove': 'Dragonstone',
#  'Willis_Wode': 'House Whent',
#  'Willow_Heddle': 'Banners',
#  'Willow_Witch_eye': 'eye',
#  'Woth': None,
#  'Wulfe': 'House Greyjoy',
#  'Wun_Weg_Wun_Dar_Wun': None,
#  'Wyl_(guard)': 'House Stark',
#  'Wylis_Manderly': 'House Manderly',
#  'Wylla': 'House Dayne',
#  'Wyman_Manderly': 'House Manderly',
#  'Wynton_Stout': "Night's Watch",
#  'Xaro_Xhoan_Daxos': 'the Thirteen',
#  'Xhondo': None,
#  'Yandry': 'House Targaryen',
#  'Yellow_Dick': 'House Bolton',
#  'Yezzan_zo_Qaggaz': 'YunkaiHouse of',
#  'Ygritte': 'Mance Rayder',
#  'Yohn_Royce': 'Lords Declarant',
#  'Yoren': "Night's Watch",
#  'Yorko_Terys': None,
#  'Ysilla': None,
#  'Yurkhaz_zo_Yunzak': 'Wise Masters',
#  'Zei': None,
#  'Zollo': 'Brave Companions'}

# %%
fromlist = []
tolist = []
for c in def_edges['Source']:
    fromlist.append(c_by_h[c.replace('-','_')])
for c in def_edges['Target']:
    try:
        tolist.append(c_by_h[c.replace('-','_')])
    except:
        pass

# %%
def_edges['FromHouse'] = fromlist
def_edges['ToHouse'] = tolist

# %%
house_csv = def_edges.to_csv('all_edges_with_house')

# %%
set(c_by_h.values())
# Out:
# {'the Peach',
#  'LannisportMaesters of',
#  'BrownhollowHouse Baelish',
#  'House Waynwood',
#  'last greenseer',
#  'Targaryen',
#  'Faceless Men',
#  'House Ironmaker',
#  'House Norrey',
#  'Huntsman',
#  'Harrenhal',
#  'House Heddle',
#  'House StarkHouse',
#  'House Estermont',
#  "R'hllor",
#  'House Clifton',
#  'Stone Crows',
#  'House Crabb',
#  'Shagwell',
#  'House Paege',
#  'three-eyed crow',
#  'House Tarly',
#  'House Stonehouse',
#  'Lords Declarant',
#  'StormcrowsHouse Targaryen',
#  'House Tallhart',
#  'House Dalt',
#  'House Bolton',
#  "Mother's Men",
#  'House Corbray',
#  'House Rowan',
#  'DreadfortHouse Bolton',
#  'Great Masters',
#  'House TargaryenHouse',
#  'Khal Drogo',
#  'Camarron',
#  "Widow's Watch",
#  'Septon',
#  'Lucky',
#  'Stiv',
#  'Mezzara',
#  'House Cassel',
#  'House Goodbrother',
#  'House Swyft',
#  'Free Brothers',
#  'Brave Companions',
#  'Grazhar',
#  "SonsIron ShieldsMaiden's",
#  'Stormcrows',
#  'House Hornwood',
#  'House Harlaw',
#  'Giant',
#  'House Allyrion',
#  'House Darry',
#  'House Merryweather',
#  'House Targaryen',
#  'House Arryn',
#  'House Stokeworth',
#  'House Tyrell',
#  'Melisandre',
#  'Casterly RockHouse',
#  'House Thenn',
#  'the Thirteen',
#  'Garth',
#  'Sevenstreams',
#  'Anguy',
#  'House Dayne',
#  'Holy Hundred',
#  'Stone men',
#  'Wise Masters',
#  'Greenbeard',
#  'Will',
#  'House Celtigar',
#  'Lem',
#  'Moon Brothers',
#  'House Kettleblack',
#  'QueensguardRuling council',
#  "Night's Watch",
#  'Myraham',
#  'Great MastersBrazen',
#  'House Oakheart',
#  'House Karstark',
#  'New Barrel',
#  'Kingswood Brotherhood',
#  'Me',
#  'House Byrch',
#  'Nurse',
#  'House Botley',
#  'House Spicer',
#  'House Grafton',
#  'Bloodbeard',
#  'House Baratheon',
#  'Owen',
#  'House Florent',
#  'Citadel',
#  'FingersHouse Baelish',
#  "Queen's men",
#  'Scolera',
#  'House Whent',
#  'Qezza',
#  'House Varner',
#  'House Dustin',
#  'White',
#  "King's men",
#  'House Lannister',
#  'eye',
#  'Banners',
#  'House Manderly',
#  'Mountain',
#  'nn',
#  'House Cerwyn',
#  'Baratheon of',
#  'House Peckledon',
#  'House Marbrand',
#  'Walgrave',
#  'Undying Ones',
#  'House Connington',
#  "Alchemists' Guild",
#  "DragonstoneQueen's men",
#  'Summer Islands',
#  'High Hermitage',
#  'House Lefford',
#  'Happy Port',
#  'House Drumm',
#  'Merrit',
#  'House of',
#  'House Darklyn',
#  'House Serry',
#  'House Westerling',
#  'Golden Company',
#  "House TullyNight's",
#  'House Mallister',
#  'Hghar',
#  'UnsulliedHouse Targaryen',
#  'House Martell',
#  'House Greyjoy',
#  'Daughter',
#  'Most Devout',
#  'Gates of',
#  'House Smallwood',
#  'House Frey',
#  'House Redbeard',
#  'Brotherhood without',
#  'House Poole',
#  'Black Ears',
#  'House Mormont',
#  'House Umber',
#  'House Yronwood',
#  'House Clegane',
#  'Dragonstone',
#  'Hareth',
#  'House Piper',
#  'House Baelish',
#  'SparrowsFaith Militant',
#  'House Crakehall',
#  'Khrazz',
#  'House Lynderly',
#  'House Prester',
#  'Brother',
#  'House Bracken',
#  'Drowned men',
#  'House Mullendore',
#  'Dyre Den',
#  'Windblown',
#  'House Hetherspoon',
#  'House Hollard',
#  'Elephants',
#  'nnsHouse Thenn',
#  'House YronwoodWindblown',
#  'House Blacktyde',
#  'House Reed',
#  'Tyrell',
#  'House TargaryenGolden',
#  'House Seaworth',
#  'House MartellWindblown',
#  'Grey Garden',
#  'House Caswell',
#  'House Hunter',
#  'House ArrynHouse',
#  'Gendry',
#  'House Sunglass',
#  'House Sparr',
#  'Second Sons',
#  "Wayfarer's Rest",
#  "King's Landing",
#  None,
#  'Brightwater Keep',
#  'YunkaiHouse of',
#  'Martell',
#  'House TargaryenShavepatesBrazen',
#  'Braavos',
#  'House Stark',
#  'House Turnberry',
#  'Burned Men',
#  'House Codd',
#  'iger',
#  'House Hewett',
#  'House Borrell',
#  'Unsullied',
#  'House Rosby',
#  "Chataya's brothel",
#  'Rainbow Guard',
#  'Tower of',
#  'Steelskin',
#  'House Velaryon',
#  'Belaquo',
#  'Galare',
#  'Robin',
#  'House Glover',
#  'House Merlyn',
#  'House TargaryenSecond',
#  'Kingsguard',
#  'Meribald',
#  'Harlaw Hall',
#  'House Ryswell',
#  'House Payne',
#  'House Longwaters',
#  'First Flints',
#  'House Redfort',
#  'Dhan',
#  'House Fowler',
#  'Ezzara',
#  'Atranta',
#  'House Tarth',
#  'City Watch',
#  'House Tully',
#  'Mance Rayder',
#  'House Blackwood',
#  'House Redwyne'}

# %%
stark_df = def_edges[(def_edges['FromHouse'] == "House Stark")]
stark_df = stark_df[stark_df['ToHouse'] == "House Stark"]

# %%
colors = ['r' if i == "House Stark" else 'b' for i in stark_df['ToHouse']]

# %%
stark_df
# Out:
#                 Source         Target        Type    id  weight    FromHouse  \
# 127           Alebelly     Bran-Stark  Undirected   127       7  House Stark
# 128           Alebelly        Hayhead  Undirected   128       3  House Stark
# 130           Alebelly         Mikken  Undirected   130       3  House Stark
# 171               Alyn   Eddard-Stark  Undirected   171      11  House Stark
# 175               Alyn         Tomard  Undirected   175       3  House Stark
# 296         Arya-Stark   Benjen-Stark  Undirected   296       3  House Stark
# 299         Arya-Stark     Bran-Stark  Undirected   299      40  House Stark
# 303         Arya-Stark  Catelyn-Stark  Undirected   303       8  House Stark
# 308         Arya-Stark        Desmond  Undirected   308       3  House Stark
# 311         Arya-Stark   Eddard-Stark  Undirected   311      46  House Stark
# 336         Arya-Stark        Mordane  Undirected   336      39  House Stark
# 339         Arya-Stark            Nan  Undirected   339      17  House Stark
# 347         Arya-Stark   Rickon-Stark  Undirected   347      20  House Stark
# 348         Arya-Stark     Robb-Stark  Undirected   348      44  House Stark
# 350         Arya-Stark  Rodrik-Cassel  Undirected   350       3  House Stark
# 354         Arya-Stark    Sansa-Stark  Undirected   354     155  House Stark
# 355         Arya-Stark    Syrio-Forel  Undirected   355      29  House Stark
# 362         Arya-Stark         Tomard  Undirected   362       6  House Stark
# 552       Benjen-Stark     Bran-Stark  Undirected   552       9  House Stark
# 557       Benjen-Stark          Luwin  Undirected   557       7  House Stark
# 559       Benjen-Stark     Robb-Stark  Undirected   559       7  House Stark
# 630         Bran-Stark  Catelyn-Stark  Undirected   630      24  House Stark
# 636         Bran-Stark   Eddard-Stark  Undirected   636      34  House Stark
# 638         Bran-Stark  Hallis-Mollen  Undirected   638       3  House Stark
# 639         Bran-Stark        Hayhead  Undirected   639       6  House Stark
# 640         Bran-Stark          Hodor  Undirected   640     209  House Stark
# 642         Bran-Stark         Hullen  Undirected   642       3  House Stark
# 650         Bran-Stark         Joseth  Undirected   650       4  House Stark
# 652         Bran-Stark          Luwin  Undirected   652     116  House Stark
# 654         Bran-Stark         Mikken  Undirected   654      11  House Stark
# ...                ...            ...         ...   ...     ...          ...
# 1635     Hallis-Mollen     Robb-Stark  Undirected  1635      13  House Stark
# 1679            Heward    Wyl-(guard)  Undirected  1679       3  House Stark
# 1712             Hodor          Luwin  Undirected  1712      27  House Stark
# 1714             Hodor            Nan  Undirected  1714       8  House Stark
# 1715             Hodor           Osha  Undirected  1715      16  House Stark
# 1716             Hodor   Rickon-Stark  Undirected  1716      11  House Stark
# 1717             Hodor     Robb-Stark  Undirected  1717       5  House Stark
# 1718             Hodor  Rodrik-Cassel  Undirected  1718       3  House Stark
# 1754            Hullen          Luwin  Undirected  1754       3  House Stark
# 1755            Hullen     Robb-Stark  Undirected  1755       3  House Stark
# 1756            Hullen  Rodrik-Cassel  Undirected  1756       3  House Stark
# 1925  Jeyne-Westerling     Robb-Stark  Undirected  1925      24  House Stark
# 2098            Joseth          Luwin  Undirected  2098       3  House Stark
# 2210             Luwin            Nan  Undirected  2210      12  House Stark
# 2211             Luwin           Osha  Undirected  2211      28  House Stark
# 2213             Luwin   Rickon-Stark  Undirected  2213      21  House Stark
# 2214             Luwin     Robb-Stark  Undirected  2214      26  House Stark
# 2215             Luwin  Rodrik-Cassel  Undirected  2215      21  House Stark
# 2223      Lyanna-Stark    Sansa-Stark  Undirected  2223       4  House Stark
# 2354            Mikken           Osha  Undirected  2354       3  House Stark
# 2373           Mordane    Sansa-Stark  Undirected  2373      47  House Stark
# 2399               Nan     Robb-Stark  Undirected  2399       4  House Stark
# 2433              Osha   Rickon-Stark  Undirected  2433       8  House Stark
# 2434              Osha     Robb-Stark  Undirected  2434       6  House Stark
# 2597      Rickon-Stark     Robb-Stark  Undirected  2597      53  House Stark
# 2598      Rickon-Stark  Rodrik-Cassel  Undirected  2598       3  House Stark
# 2599      Rickon-Stark    Sansa-Stark  Undirected  2599      20  House Stark
# 2605        Robb-Stark  Rodrik-Cassel  Undirected  2605      27  House Stark
# 2612        Robb-Stark    Sansa-Stark  Undirected  2612      44  House Stark
# 2701       Sansa-Stark         Tomard  Undirected  2701       3  House Stark
#
#           ToHouse
# 127   House Stark
# 128   House Stark
# 130   House Stark
# 171   House Stark
# 175   House Stark
# 296   House Stark
# 299   House Stark
# 303   House Stark
# 308   House Stark
# 311   House Stark
# 336   House Stark
# 339   House Stark
# 347   House Stark
# 348   House Stark
# 350   House Stark
# 354   House Stark
# 355   House Stark
# 362   House Stark
# 552   House Stark
# 557   House Stark
# 559   House Stark
# 630   House Stark
# 636   House Stark
# 638   House Stark
# 639   House Stark
# 640   House Stark
# 642   House Stark
# 650   House Stark
# 652   House Stark
# 654   House Stark
# ...           ...
# 1635  House Stark
# 1679  House Stark
# 1712  House Stark
# 1714  House Stark
# 1715  House Stark
# 1716  House Stark
# 1717  House Stark
# 1718  House Stark
# 1754  House Stark
# 1755  House Stark
# 1756  House Stark
# 1925  House Stark
# 2098  House Stark
# 2210  House Stark
# 2211  House Stark
# 2213  House Stark
# 2214  House Stark
# 2215  House Stark
# 2223  House Stark
# 2354  House Stark
# 2373  House Stark
# 2399  House Stark
# 2433  House Stark
# 2434  House Stark
# 2597  House Stark
# 2598  House Stark
# 2599  House Stark
# 2605  House Stark
# 2612  House Stark
# 2701  House Stark
#
# [99 rows x 7 columns]

# %%
def draw_and_score_graph(df):
    G = nx.DiGraph(
                    nx.convert_matrix.from_pandas_dataframe(
                                                            df, source = "Source", target = "Target"))
    data = json_graph.node_link_data(G)
    H = json_graph.node_link_graph(data)

    weights = dict(zip(df['weight'], df['weight']))

    nx.set_edge_attributes(G, 'weight', weights.values())
    
    nx.draw_networkx(H)
    degs = nx.degree(G)
    degs = [(degs[node]+1) * 100 for node in G.nodes()]
    
    pos = nx.circular_layout(G)
    
    plt.figure(1, figsize = (20,20))
    nx.draw(starkG, pos, with_labels = True, node_size = degs)
    
    deg_cent = sorted(nx.degree_centrality(G).items(), key=lambda x: x[1], reverse = True)[:25]
    clo_cent = sorted(nx.closeness_centrality(G).items(), key=lambda x: x[1], reverse = True)[:25]
    btw_cen = sorted(nx.betweenness_centrality(G).items(), key=lambda x: x[1], reverse = True)[:25]
    eig_cen = sorted(nx.eigenvector_centrality(G).items(), key=lambda x: x[1], reverse = True)[:25]
    pgr = sorted(nx.pagerank(G).items(), key=lambda x: x[1], reverse = True)
    
    most_central = list(set([i[0] for i in deg_cent])|
                             set([i[0] for i in clo_cent])|
                             set([i[0] for i in btw_cent])|
                             set([i[0] for i in eig_cent])|
                             set([i[0] for i in pgr]))

# %%
#nx.draw(starkH)  
#nx.draw_random(starkH)  
  
#nx.draw_spectral(starkH)  
#nx.draw_spring(starkH)

# %%
sorted(nx.betweenness_centrality(G).items(), key=lambda x: x[1], reverse = True)[:10]
# Out:
# [('Jon-Snow', 0.2090235052407737),
#  ('Tyrion-Lannister', 0.1618222237081112),
#  ('Daenerys-Targaryen', 0.09760586606194271),
#  ('Stannis-Baratheon', 0.09622991565902604),
#  ('Jaime-Lannister', 0.09569370342852695),
#  ('Theon-Greyjoy', 0.09532046763707933),
#  ('Cersei-Lannister', 0.0890004559093355),
#  ('Robb-Stark', 0.07609258343606788),
#  ('Robert-Baratheon', 0.07195991469430654),
#  ('Arya-Stark', 0.0691271381325718)]

# %%
pos
# Out:
# {'Alebelly': array([  9.99999992e-01,   1.52599657e-08]),
#  'Alyn': array([ 0.76604443,  0.64278758]),
#  'Arya-Stark': array([ 0.34202016,  0.93969262]),
#  'Benjen-Stark': array([ 0.17364823,  0.98480773]),
#  'Bran-Stark': array([ 0.98480772,  0.17364819]),
#  'Brandon-Stark': array([-0.17364812, -0.98480776]),
#  'Catelyn-Stark': array([ -3.66196120e-08,   1.00000000e+00]),
#  'Cayn': array([ 0.3420201 , -0.93969259]),
#  'Desmond': array([-0.17364818,  0.98480773]),
#  'Eddard-Stark': array([ 0.64278763,  0.76604444]),
#  'Hallis-Mollen': array([-0.98480771, -0.17364821]),
#  'Hayhead': array([ 0.93969261,  0.34202013]),
#  'Heward': array([ 0.98480778, -0.17364795]),
#  'Hodor': array([-0.9396926 , -0.34202013]),
#  'Hullen': array([-0.86602537, -0.49999995]),
#  'Jacks': array([ 0.49999991, -0.86602542]),
#  'Jeyne-Westerling': array([ 0.17364815, -0.9848077 ]),
#  'Joseth': array([-0.76604448, -0.64278755]),
#  'Luwin': array([ -9.99999978e-01,  -7.21628095e-08]),
#  'Lyanna-Stark': array([  1.90166561e-08,  -9.99999969e-01]),
#  'Mikken': array([ 0.86602538,  0.50000001]),
#  'Mordane': array([-0.34202011,  0.93969262]),
#  'Nan': array([-0.50000004,  0.86602539]),
#  'Osha': array([-0.6427875 , -0.76604453]),
#  'Porther': array([ 0.64278751, -0.76604447]),
#  'Poxy-Tym': array([-0.4999999 , -0.86602542]),
#  'Rickard-Stark': array([-0.34202005, -0.93969265]),
#  'Rickon-Stark': array([-0.64278762,  0.76604444]),
#  'Robb-Stark': array([-0.76604442,  0.64278764]),
#  'Rodrik-Cassel': array([-0.86602537,  0.50000007]),
#  'Sansa-Stark': array([-0.9396926 ,  0.34202022]),
#  'Syrio-Forel': array([-0.98480771,  0.17364831]),
#  'Tomard': array([ 0.49999997,  0.86602545]),
#  'Torrhen-Stark': array([ 0.76604431, -0.64278773]),
#  'Varly': array([ 0.86602532, -0.50000016]),
#  'Wyl-(guard)': array([ 0.93969255, -0.34202034])}

# %%
nx.draw(nx.ego_graph(G, 'Janos-Slynt', radius = 1))

# %%
list(set(np.append(def_edges['ToHouse'].unique(), def_edges['FromHouse'].unique())))
# Out:
# ['the Peach',
#  'LannisportMaesters of',
#  'BrownhollowHouse Baelish',
#  'House Waynwood',
#  'last greenseer',
#  'Targaryen',
#  'House Ironmaker',
#  'Faceless Men',
#  'House Norrey',
#  'Huntsman',
#  'Harrenhal',
#  'House Heddle',
#  'House StarkHouse',
#  'House Estermont',
#  "R'hllor",
#  'House Clifton',
#  'Stone Crows',
#  'House Crabb',
#  'Shagwell',
#  'House Paege',
#  'three-eyed crow',
#  'House Tarly',
#  'House Stonehouse',
#  'Lords Declarant',
#  'StormcrowsHouse Targaryen',
#  'House Tallhart',
#  "Mother's Men",
#  'House Bolton',
#  'House Dalt',
#  'Great Masters',
#  'House Rowan',
#  'DreadfortHouse Bolton',
#  'House Corbray',
#  'House TargaryenHouse',
#  'Khal Drogo',
#  'Camarron',
#  "Widow's Watch",
#  'Septon',
#  'Lucky',
#  'Stiv',
#  'Mezzara',
#  'House Goodbrother',
#  'House Cassel',
#  'House Swyft',
#  'Free Brothers',
#  'Brave Companions',
#  "SonsIron ShieldsMaiden's",
#  'Grazhar',
#  'Stormcrows',
#  'House Hornwood',
#  'House Harlaw',
#  'Giant',
#  'House Allyrion',
#  'House Darry',
#  'House Merryweather',
#  'House Targaryen',
#  'House Arryn',
#  'House Stokeworth',
#  'House Tyrell',
#  'Melisandre',
#  'Casterly RockHouse',
#  'House Thenn',
#  'the Thirteen',
#  'Sevenstreams',
#  'Garth',
#  'Anguy',
#  'House Dayne',
#  'Holy Hundred',
#  'Stone men',
#  'Lem',
#  'Greenbeard',
#  'Wise Masters',
#  'Will',
#  'House Celtigar',
#  'Moon Brothers',
#  'QueensguardRuling council',
#  'House Kettleblack',
#  "Night's Watch",
#  'Myraham',
#  'Great MastersBrazen',
#  'House Oakheart',
#  'House Karstark',
#  'Nurse',
#  'Kingswood Brotherhood',
#  'Me',
#  'House Byrch',
#  'House Spicer',
#  'House Botley',
#  'New Barrel',
#  'House Grafton',
#  'Bloodbeard',
#  'House Baratheon',
#  'House Florent',
#  'Citadel',
#  "Queen's men",
#  'FingersHouse Baelish',
#  'Scolera',
#  'House Whent',
#  'Qezza',
#  'House Dustin',
#  'House Varner',
#  'White',
#  "King's men",
#  'House Lannister',
#  'eye',
#  'Banners',
#  'House Manderly',
#  'House Cerwyn',
#  'nn',
#  'Mountain',
#  'Baratheon of',
#  'House Peckledon',
#  'House Marbrand',
#  'Walgrave',
#  'Undying Ones',
#  'House Connington',
#  'Summer Islands',
#  "Alchemists' Guild",
#  'High Hermitage',
#  "DragonstoneQueen's men",
#  'House Lefford',
#  'House Drumm',
#  'House of',
#  'Happy Port',
#  'Merrit',
#  'House Darklyn',
#  'House Serry',
#  'House Westerling',
#  'Golden Company',
#  "House TullyNight's",
#  'House Mallister',
#  'Hghar',
#  'UnsulliedHouse Targaryen',
#  'House Greyjoy',
#  'House Martell',
#  'Daughter',
#  'Most Devout',
#  'House Smallwood',
#  'Gates of',
#  'House Frey',
#  'Brotherhood without',
#  'House Redbeard',
#  'House Poole',
#  'Black Ears',
#  'House Mormont',
#  'House Umber',
#  'Dragonstone',
#  'House Clegane',
#  'House Yronwood',
#  'Hareth',
#  'House Piper',
#  'House Baelish',
#  'SparrowsFaith Militant',
#  'House Crakehall',
#  'Khrazz',
#  'House Lynderly',
#  'House Prester',
#  'Brother',
#  'House Bracken',
#  'Drowned men',
#  'House Mullendore',
#  'Dyre Den',
#  'Windblown',
#  'House YronwoodWindblown',
#  'House Hollard',
#  'House Hetherspoon',
#  'nnsHouse Thenn',
#  'Elephants',
#  'House Blacktyde',
#  'House Reed',
#  'Tyrell',
#  'House TargaryenGolden',
#  'House Seaworth',
#  'House MartellWindblown',
#  'Grey Garden',
#  'Gendry',
#  'House Hunter',
#  'House ArrynHouse',
#  'House Caswell',
#  'House Sunglass',
#  'House Sparr',
#  'Second Sons',
#  "Wayfarer's Rest",
#  "King's Landing",
#  None,
#  'Brightwater Keep',
#  'House Blackwood',
#  'YunkaiHouse of',
#  'Martell',
#  'House TargaryenShavepatesBrazen',
#  'Braavos',
#  'House Stark',
#  'House Turnberry',
#  'Burned Men',
#  'House Codd',
#  "Chataya's brothel",
#  'House Hewett',
#  'Unsullied',
#  'Steelskin',
#  'House Rosby',
#  'House Borrell',
#  'Rainbow Guard',
#  'Tower of',
#  'iger',
#  'House Velaryon',
#  'Belaquo',
#  'Galare',
#  'House Merlyn',
#  'House Glover',
#  'Robin',
#  'House TargaryenSecond',
#  'Kingsguard',
#  'Meribald',
#  'Harlaw Hall',
#  'House Payne',
#  'House Ryswell',
#  'House Longwaters',
#  'First Flints',
#  'House Fowler',
#  'House Redfort',
#  'Dhan',
#  'Ezzara',
#  'Atranta',
#  'House Tarth',
#  'City Watch',
#  'House Tully',
#  'Mance Rayder',
#  'Owen',
#  'House Redwyne']

# %%
def_edges.columns
# Out:
# Index(['Source', 'Target', 'Type', 'id', 'weight', 'FromHouse', 'ToHouse'], dtype='object')
